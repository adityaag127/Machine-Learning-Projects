# %%
import pandas as pd

# %%
df=pd.read_csv("test_score.csv")
df
# Out:
#      name  math  cs
# 0   david     1   5
# 1   laura     2   7
# 2  sanjay     3   9
# 3     wel     4  11
# 4    jeff     5  13

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
x=df[["math"]]
y=df[["cs"]]
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[2.]])

# %%
lr.intercept_
# Out:
# array([3.])

# %% [markdown]
# ## We can find these intercept and coffecient by doing some code or we can say that mathematics

# %%
import numpy as np

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    it=10000+1
    n=len(x)
    learn=0.08
    for i in range(it):
        y_pred=m_curr*x+b_curr
        md=-(2/n)*sum(x*(y-y_pred))
        bd=-(2/n)*sum(y-y_pred)
        m_curr=m_curr-learn*md
        b_curr=b_curr-learn*bd
        print("m {},b {},it {}".format(m_curr,b_curr,i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m 4.96,b 1.44,it 0
# m 0.4991999999999983,b 0.26879999999999993,it 1
# m 4.451584000000002,b 1.426176000000001,it 2
# m 0.892231679999997,b 0.5012275199999995,it 3
# m 4.041314713600002,b 1.432759910400001,it 4
# m 1.2008760606719973,b 0.7036872622079998,it 5
# m 3.7095643080294423,b 1.4546767911321612,it 6
# m 1.4424862661541864,b 0.881337636696883,it 7
# m 3.4406683721083144,b 1.4879302070713722,it 8
# m 1.6308855378034224,b 1.0383405553279617,it 9
# m 3.2221235247119777,b 1.5293810083298451,it 10
# m 1.7770832372205707,b 1.1780607551353204,it 11
# m 3.0439475772474127,b 1.5765710804477953,it 12
# m 1.8898457226770244,b 1.3032248704973899,it 13
# m 2.898169312926714,b 1.6275829443328358,it 14
# m 1.9761515088959358,b 1.4160484030347593,it 15
# m 2.7784216197824048,b 1.6809279342791488,it 16
# m 2.0415541605113807,b 1.5183370872989306,it 17
# m 2.6796170361078637,b 1.735457156285639,it 18
# m 2.090471617540917,b 1.611567833948162,it 19
# ...

# %% [markdown]
# ## As we see that m=2 and b is nearly equal to 3 that we already find by ML keys Linear Regression
