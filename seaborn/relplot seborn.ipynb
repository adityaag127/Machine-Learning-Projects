# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style="darkgrid")

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.relplot(x="total_bill",y="tip",data=tips)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'legend',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
#  'tight_layout']

# %%
sns.relplot(x="total_bill",y='tip',data=tips,hue="smoker")##hue is for color

# %%
sns.relplot(x="total_bill",y='tip',data=tips,hue="smoker",style="time")## style is for style

# %%
sns.relplot(x="total_bill",y='tip',data=tips,hue="size")

# %%
sns.relplot(x="total_bill",y='tip',data=tips,hue="size",palette='ch:r=-0.5,l=0.95')## palette is use to change default size of hue

# %%
sns.relplot(x='total_bill',y="tip",data=tips,size="size")##size is for changing size

# %%
sns.relplot(x='total_bill',y="tip",data=tips,size="size",sizes=(15,200))## sizes is use to change the default size of size

# %%
##next

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(dict(time=np.arange(500),value=randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0 -0.392224
# 1     1  0.249140
# 2     2 -0.946411
# 3     3 -1.015372
# 4     4 -0.423847

# %%
sns.relplot(x='time',y='value',kind="line",data=df)

# %%
df=pd.DataFrame(randn(500,2).cumsum(axis=0),columns=['time','value'])

# %%
df.head()
# Out:
#        time     value
# 0 -0.303724  0.007510
# 1 -2.065649  0.169304
# 2 -1.733296 -0.085967
# 3 -0.975999  1.662286
# 4 -2.590999  2.121287

# %%
## By default soted according to x axis
sns.relplot(x='time',y='value',kind="line",data=df)

# %%
sns.relplot(x='time',y='value',kind="line",data=df,sort=False)

# %%
fmri=sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",ci=False)

# %%
#standard deviation
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",ci="sd")

# %%
sns.relplot(x="timepoint",y="signal",estimator=None,kind="line",data=fmri)

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",hue="event")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",size="event")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event",hue="region")

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event",hue="region",markers=True)

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event",hue="region",markers=True,dashes=False)

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,kind="line",style="event",hue="event")

# %%
sns.relplot(x="timepoint",y="signal",hue="region",units="subject",estimator=None,kind="line",data=fmri.query("event == 'stim'"))

# %%
dots=sns.load_dataset("dots").query("align=='dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x="time",y="firing_rate",data=dots,kind="line",hue="coherence",style="choice")

# %%
palette=sns.cubehelix_palette(light=0.8,n_colors=6)
sns.relplot(x="time",y="firing_rate",data=dots,kind="line",hue="coherence",style="choice",palette=palette)

# %%
sns.relplot(x="time",y="firing_rate",data=dots,kind="line",size="coherence",style="choice",sizes=(1,5))

# %% [markdown]
# ## ploting data when x axis in date and time format

# %%
df=pd.DataFrame(dict(time=pd.date_range('2019-06-02',periods=500),value=randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2019-06-02  0.858549
# 1 2019-06-03 -1.418824
# 2 2019-06-04  0.379818
# 3 2019-06-05 -0.507455
# 4 2019-06-06 -0.068868

# %%
g=sns.relplot(x="time",y="value",kind="line",data=df)

# %%
g=sns.relplot(x="time",y="value",kind="line",data=df)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",col="time")## col is use to seprate the plot on classifier columns

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",col="day")

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",col="day",col_wrap=3,height=3)

# %%
sns.relplot(x="total_bill",y="tip",data=tips,hue="smoker",row="time")## col is use to seprate the plot on classifier columns

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint",y="signal",data=fmri,hue="subject",col="region",row="event",height=3,kind="line",estimator=None)

# %% [markdown]
# ## Now lineplot

# %%
sns.lineplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x="total_bill",y="tip",data=tips,kind="line",height=3)## relplot kind="line" and line plot are same

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x="total_bill",y="tip",data=tips,height=3)## relpot of scatter and sctterplot are same

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x="timepoint",y="signal",data=fmri,hue="event",style="region",marker=True,ci=20,err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",units="subject",data=fmri,estimator=None)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Above lineplot and scatter plot are same thing as in relplot

# %%
iris=sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x="sepal_length",y="petal_length",data=iris)

# %%
sns.relplot(x=iris["sepal_length"],y=iris["petal_length"])
